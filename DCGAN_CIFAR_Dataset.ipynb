# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3

# %% [markdown]
# # Load CIFAR-10 Dataset
#
# ### **CIFAR-10 Dataset**: It consists of 60,000 32x32 color images in 10 classes. Here, only the training set (X_train) is used, and the images are normalized to values between 0 and 1 to improve training stability.

# %%
# Load CIFAR-10 dataset
(X_train, y_train), (_, _) = tf.keras.datasets.cifar10.load_data()
X_train = (X_train.astype(np.float32) - 127.5) / 127.5  # Normalize to [-1, 1]

# %% [markdown]
# # Build Generator
#
# ### The **generator** creates images that resemble real data from a random noise vector (input_dim=100), also called a latent space. It uses Convolutional Transpose layers (also known as deconvolution or upsampling layers) to gradually increase the spatial dimensions and convert the input noise into a 32x32 RGB image.
#
# ### ***Dense(256 * 8 * 8)***: The noise vector is transformed into a 256-channel feature map of shape 8x8.
#
# ### ***Reshape((8, 8, 256))***: Reshapes the dense output into a 3D feature map.
#
# ### ***Conv2DTranspose***: These layers upsample the feature maps to 16x16 and 32x32. Strides of 2 are used to double the spatial dimensions.
#
# ### ***Conv2D(3)***: The output is a 32x32 image with 3 channels (RGB). Tanh activation scales the pixel values to the range [-1, 1] to match the normalized CIFAR-10 images.

# %% [markdown]
# # **Select Specific Class**

# %%
specific_class = 1
X_train = X_train[y_train.flatten() == specific_class]

# Define Data Augmentation for Discriminator
data_augmentation = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
)

# %%
# Generator model (DCGAN)
def build_generator():
    model = tf.keras.Sequential()
    model.add(layers.Dense(8 * 8 * 256, input_dim=100))
    model.add(layers.Reshape((8, 8, 256)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.2))

    model.add(layers.Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.2))

    model.add(layers.Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU(alpha=0.2))

    model.add(layers.Conv2DTranspose(3, (4, 4), strides=(1, 1), padding='same', activation='tanh'))

    return model

generator = build_generator()

# %% [markdown]
# # Building the Discriminator
#
# ### The **discriminator** tries to differientiate between real and generated (fake) images. It outputs a probability between 0 (fake) and 1 (real) using a sigmoid activation.
#
# ### ***Conv2D(64)***: Applies convolution with a kernel size of 5 and a stride of 2 to downsample the 32x32 image to 16x16.
#
# ### ***LeakyReLU(0.2)***: An activation function similar to ReLU, but with a small slope for negative values (alpha = 0.2). This prevents neurons from dying during training (which can happen with ReLU).
#
# ### ***Conv2D(128)***: Further downsampling the feature map from 16x16 to 8x8.
#
# ### ***Flatten()***: Converts the 3D feature maps into a 1D vector for the dense output layer.
#
# ### ***Dense(1, sigmoid)***: Produces a single output between 0 and 1 representing whether the input image is real or fake.

# %%
# Discriminator model (DCGAN)
def build_discriminator():
    model = tf.keras.Sequential([
        layers.Conv2D(64, (4, 4), strides=(2, 2), padding='same', input_shape=(32, 32, 3)),
        layers.LeakyReLU(alpha=0.2),

        layers.Conv2D(128, (4, 4), strides=(2, 2), padding='same'),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),

        layers.Conv2D(256, (4, 4), strides=(2, 2), padding='same'),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),

        layers.Conv2D(512, (4, 4), strides=(2, 2), padding='same'),
        layers.BatchNormalization(),
        layers.LeakyReLU(alpha=0.2),

        layers.Flatten(),
        layers.Dense(1, activation='sigmoid')
    ])
    return model




# Call the discriminator
discriminator = build_discriminator()
discriminator.summary()
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)                   │ (None, 16, 16, 64)          │           3,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_41 (LeakyReLU)           │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 8, 8, 128)           │         131,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_36               │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_42 (LeakyReLU)           │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 4, 4, 256)           │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_37               │ (None, 4, 4, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_43 (LeakyReLU)           │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 2, 2, 512)           │       2,097,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_38               │ (None, 2, 2, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_44 (LeakyReLU)           │ (None, 2, 2, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_5 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 1)                   │           2,049 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,762,177 (10.54 MB)
#  Trainable params: 2,760,385 (10.53 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %% [markdown]
# # Compile the Models
#
# ### The ***discriminator is compiled with the binary cross-entropy loss function since it performs binary classification*** (real vs. fake). The Adam optimizer is used to optimize the model.

# %%
# Build and compile models
generator = build_generator()
discriminator = build_discriminator()

discriminator.compile(optimizer=tf.keras.optimizers.Adam(0.0002), loss='binary_crossentropy', metrics=['accuracy'])
discriminator.trainable = False

gan_input = layers.Input(shape=(100,))
generated_image = generator(gan_input)
gan_output = discriminator(generated_image)

gan = tf.keras.Model(gan_input, gan_output)
gan.compile(optimizer=tf.keras.optimizers.Adam(0.0002), loss='binary_crossentropy')

# %% [markdown]
# # **Function to compute Inception Score**

# %%
def inception_score(images, splits=10):
    inception_model = InceptionV3(include_top=False, pooling='avg')
    preds = inception_model.predict(images)
    scores = []
    for i in range(splits):
        part = preds[(i * preds.shape[0] // splits): ((i + 1) * preds.shape[0] // splits)]
        kl_div = part * (np.log(part) - np.log(np.expand_dims(part.mean(axis=0), 0)))
        kl_div = np.mean(np.sum(kl_div, axis=1))
        scores.append(np.exp(kl_div))
    return np.mean(scores), np.std(scores)

# %% [markdown]
# # Train the function
#
# ### ***Noise Generation***: A batch of random noise vectors is generated and passed through the generator to produce fake images.
#
# ### ***Discriminator Training***: The discriminator is trained on both real and fake images. The real images are labeled as 0.9 (soft label, slightly less than 1 to prevent overconfidence), and the fake images are labeled as 0. Both are concatenated into one batch.
#
# ### ***Generator Training***: The generator tries to fool the discriminator, so it’s trained with the goal that the discriminator labels the generated images as real (1). During this phase, the discriminator's weights are frozen (discriminator.trainable = False).
#
# ### ***Loss Calculation***: After each epoch, the losses of both the discriminator (d_loss) and generator (g_loss) are printed.

# %%
# Training function
def train(epochs, batch_size=128, save_interval=200):
    real = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))

    for epoch in range(epochs):
        idx = np.random.randint(0, X_train.shape[0], batch_size)
        real_images = X_train[idx]
        real_images = data_augmentation.flow(real_images, batch_size=batch_size).next()

        noise = np.random.normal(0, 1, (batch_size, 100))
        fake_images = generator.predict(noise)

        d_loss_real = discriminator.train_on_batch(real_images, real)
        d_loss_fake = discriminator.train_on_batch(fake_images, fake)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        g_loss = gan.train_on_batch(noise, real)

        if epoch % save_interval == 0:
            print(f"{epoch} [D loss: {d_loss[0]}, acc.: {100 * d_loss[1]}%] [G loss: {g_loss}]")
            save_images(epoch)

            # Calculate and print Inception Score
            is_mean, is_std = inception_score(fake_images)
            print(f"Inception Score: {is_mean} ± {is_std}")

# %% [markdown]
# # Image Generation Function
#
# ### This function generates images from random noise using the generator and plots them in a grid using Matplotlib. The images are rescaled from the [-1, 1] range (from the tanh activation) back to [0, 1] for viewing.

# %%
# Function to save generated images
def save_images(epoch):
    noise = np.random.normal(0, 1, (25, 100))
    gen_images = generator.predict(noise)
    gen_images = 0.5 * gen_images + 0.5  # Rescale from [-1, 1] to [0, 1]

    fig, axs = plt.subplots(5, 5)
    cnt = 0
    for i in range(5):
        for j in range(5):
            axs[i, j].imshow(gen_images[cnt, :, :, :])
            axs[i, j].axis('off')
            cnt += 1
    plt.show()

# Train the DCGAN
train(epochs=1000, batch_size=64, save_interval=1000)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 318ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 0 [D loss: 0.6946489214897156, acc.: 35.546875%] [G loss: [array(0.6941788, dtype=float32), array(0.6941788, dtype=float32), array(0.3359375, dtype=float32)]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7a6031fa6f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7a6031e9a8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 255ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 273ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 281ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 255ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 289ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 273ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 273ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 265ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 273ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 276ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 273ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 265ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 435ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 333ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 348ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 255ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 321ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 238ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 255ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 281ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step

# %% [markdown]
# # Question 01
#
# ## **Modify the DCGAN to generate images for a specific class (e.g., cars, airplanes). Generate 10 examples of each class and analyze the quality and variety of the generated images.**
#
# ---
#
# # Question 02
#
# ## **Apply data augmentation (random cropping, flipping, etc.) to the real CIFAR-10 images during discriminator training. Evaluate if augmentation improves the discriminator's performance and results in better-generated images.**
#
# ---
#
# # Question 03
#
# ## **Implement the Inception Score to evaluate the quality of generated images. Train the DCGAN and compute the IS at various points (e.g., 2000, 5000, 10000 epochs). Compare the IS values with the visual quality of generated images.**
#
# ---
#
# # Question 04
#
# ## **Add more layers to the generator and discriminator to create deeper models. Train the deeper DCGAN and observe if this complexity improves the quality of generated images.**
